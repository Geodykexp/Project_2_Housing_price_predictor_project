# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Housing_cleaned.csv')
df
# Out:
#      Unnamed: 0     price  area  bedrooms  bathrooms  stories  mainroad  \
# 0             0  13300000  7420         4          2        3         1
# 1             1  12250000  8960         4          4        4         1
# 2             2  12250000  9960         3          2        2         1
# 3             3  12215000  7500         4          2        2         1
# 4             4  11410000  7420         4          1        2         1
# ..          ...       ...   ...       ...        ...      ...       ...
# 540         540   1820000  3000         2          1        1         1
# 541         541   1767150  2400         3          1        1         2
# 542         542   1750000  3620         2          1        1         1
# 543         543   1750000  2910         3          1        1         2
# 544         544   1750000  3850         3          1        2         1
#
#      guestroom  basement  hotwaterheating  airconditioning  parking  prefare  \
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          2
# 1    12250000  8960         4          4        4         1          2
# 2    12250000  9960         3          2        2         1          2
# 3    12215000  7500         4          2        2         1          2
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          2
# 541   1767150  2400         3          1        1         2          2
# 542   1750000  3620         2          1        1         1          2
# 543   1750000  2910         3          1        1         2          2
# 544   1750000  3850         3          1        2         1          2
#
#      basement  hotwaterheating  airconditioning  parking  prefare  \
# ...

# %%
new_order = ['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefare', 'furnishingstatus', 'price']

# %%
df1 = df[new_order]
df1
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          2         2
# 1    8960         4          4        4         1          2         2
# 2    9960         3          2        2         1          2         1
# 3    7500         4          2        2         1          2         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          2         1
# 541  2400         3          1        1         2          2         2
# 542  3620         2          1        1         1          2         2
# 543  2910         3          1        1         2          2         2
# 544  3850         3          1        2         1          2         2
#
#      hotwaterheating  airconditioning  parking  prefare  furnishingstatus  \
# ...

# %%
df2 = df1.iloc[:,:-1]

# %%
df2.loc[:, 'B'] = 1
df2
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          2         2
# 1    8960         4          4        4         1          2         2
# 2    9960         3          2        2         1          2         1
# 3    7500         4          2        2         1          2         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          2         1
# 541  2400         3          1        1         2          2         2
# 542  3620         2          1        1         1          2         2
# 543  2910         3          1        1         2          2         2
# 544  3850         3          1        2         1          2         2
#
#      hotwaterheating  airconditioning  parking  prefare  furnishingstatus  B
# ...

# %%
X = np.array(df2)
X
# Out:
# array([[7420,    4,    2, ...,    1,    1,    1],
#        [8960,    4,    4, ...,    2,    1,    1],
#        [9960,    3,    2, ...,    1,    2,    1],
#        ...,
#        [3620,    2,    1, ...,    2,    3,    1],
#        [2910,    3,    1, ...,    2,    1,    1],
#        [3850,    3,    1, ...,    2,    3,    1]], shape=(545, 13))

# %%
Y = (df1.iloc[:,12:]).to_numpy()
Y
# Out:
# array([[13300000],
#        [12250000],
#        [12250000],
#        [12215000],
#        [11410000],
#        [10850000],
#        [10150000],
#        [10150000],
#        [ 9870000],
#        [ 9800000],
#        [ 9800000],
#        [ 9681000],
#        [ 9310000],
#        [ 9240000],
#        [ 9240000],
#        [ 9100000],
#        [ 9100000],
#        [ 8960000],
#        [ 8890000],
#        [ 8855000],
#        [ 8750000],
#        [ 8680000],
#        [ 8645000],
#        [ 8645000],
#        [ 8575000],
#        [ 8540000],
#        [ 8463000],
#        [ 8400000],
#        [ 8400000],
#        [ 8400000],
#        [ 8400000],
#        [ 8400000],
#        [ 8295000],
#        [ 8190000],
#        [ 8120000],
#        [ 8080940],
#        [ 8043000],
#        [ 7980000],
#        [ 7962500],
#        [ 7910000],
#        [ 7875000],
#        [ 7840000],
#        [ 7700000],
#        [ 7700000],
#        [ 7560000],
#        [ 7560000],
#        [ 7525000],
# ...

# %%
Transpose = X.T
Transpose
# Out:
# array([[7420, 8960, 9960, ..., 3620, 2910, 3850],
#        [   4,    4,    3, ...,    2,    3,    3],
#        [   2,    4,    2, ...,    1,    1,    1],
#        ...,
#        [   1,    2,    1, ...,    2,    2,    2],
#        [   1,    1,    2, ...,    3,    1,    3],
#        [   1,    1,    1, ...,    1,    1,    1]], shape=(13, 545))

# %%
product = np.dot(Transpose, X)
product
# Out:
# array([[17019775719,     8455593,     3725502,     5154155,     3084741,
#             5051077,     4603604,     5487608,     4606065,     2305939,
#             4837217,     5655708,     2807045],
#        [    8455593,        5088,        2154,        3060,        1846,
#                2932,        2647,        3154,        2692,        1169,
#                2839,        3307,        1616],
#        [    3725502,        2154,        1039,        1343,         796,
#                1264,        1143,        1366,        1157,         528,
#                1230,        1421,         701],
#        [    5154155,        3060,        1343,        2186,        1103,
#                1785,        1662,        1921,        1593,         701,
#                1728,        1999,         984],
#        [    3084741,        1846,         796,        1103,         776,
#                1140,        1030,        1215,        1057,         398,
#                1114,        1310,         622],
# ...

# %%
inverse = np.linalg.inv(product)
inverse
# Out:
# array([[ 5.17260546e-10, -1.21797618e-07, -2.16438861e-07,
#          1.02909182e-07,  6.11865771e-07,  2.39157023e-07,
#         -1.90167844e-07, -4.36509341e-08,  2.93840460e-07,
#         -3.25108379e-07,  3.98067864e-07,  6.94632024e-08,
#         -4.06138041e-06],
#        [-1.21797618e-07,  4.61467819e-03, -1.46759172e-03,
#         -1.43483463e-03, -1.10604364e-03, -1.92352033e-04,
#          9.74690430e-04,  2.79938054e-04, -8.40491401e-05,
#         -2.64305610e-04,  1.48288821e-04,  1.46771156e-04,
#         -9.36024325e-03],
#        [-2.16438861e-07, -1.46759172e-03,  9.36723208e-03,
#         -1.19893071e-03, -5.79964536e-04,  5.32094128e-04,
#          9.07768177e-04,  1.12890297e-03,  4.63447315e-04,
#         -4.69631961e-04, -2.48970028e-04,  2.77265436e-04,
#         -9.01773725e-03],
#        [ 1.02909182e-07, -1.43483463e-03, -1.19893071e-03,
#          3.61037731e-03,  1.13629995e-03,  4.36148527e-04,
#         -1.72631937e-03,  3.99568811e-04,  1.46827181e-03,
# ...

# %%
product1 = np.dot(inverse, Transpose)
product1
# Out:
# array([[-1.00950774e-07,  4.38621413e-07,  1.78525096e-06, ...,
#         -3.31273629e-07, -3.47386868e-07, -2.31192140e-07],
#        [ 1.65595272e-03, -3.01765048e-03, -2.74522521e-03, ...,
#         -1.88691851e-03,  1.41465003e-03,  1.26491159e-03],
#        [ 2.75363635e-03,  1.92372520e-02,  4.70334865e-03, ...,
#          1.25018889e-03, -1.19822665e-03, -1.46611448e-03],
#        ...,
#        [-8.05413765e-03,  3.91089341e-03, -5.81149869e-03, ...,
#          1.17944721e-03, -4.44974273e-04,  1.62461196e-03],
#        [-2.36059078e-03, -1.45775148e-03,  9.90740295e-04, ...,
#          2.31473820e-03, -5.24411781e-03,  2.58735243e-03],
#        [-3.12804667e-03, -5.29909328e-02, -2.59303341e-02, ...,
#          2.15063952e-03, -1.12536931e-02, -1.26564131e-02]],
#       shape=(13, 545))

# %%
matrix = np.dot(product1, Y)
matrix
# Out:
# array([[ 2.43906887e+02],
#        [ 1.19474386e+05],
#        [ 9.88888287e+05],
#        [ 4.50391518e+05],
#        [-4.23100741e+05],
#        [-2.98030507e+05],
#        [-3.57926360e+05],
#        [-8.72936027e+05],
#        [-8.53633595e+05],
#        [ 2.79785637e+05],
#        [-6.47055599e+05],
#        [-2.13187781e+05],
#        [ 7.22041995e+06]])

# %%
matrix.shape
# Out:
# (13, 1)

# %%
# Where Y(lINEAR) = W1X1 + W2X2 + W3X3 + W4X4 + W5X5 + W6X6 + W7X7 + W8X8 + W9X9 + W10X10 + W11X11 + W12X12 + B
W1 = 2.43906887e+02
W2 = 1.19474386e+05
W3 = 9.88888287e+05
W4 = 4.50391518e+05
W5 = -4.23100741e+05
W6 = -2.98030507e+05
W7 = -3.57926360e+05
W8 = -8.72936027e+05
W9 = -8.53633595e+05
W10 = 2.79785637e+05
W11 = -6.47055599e+05
W12 = -2.13187781e+05
B = 7.22041995e+06

# %% [markdown]
# # Substituting answer into equation

# %%
df1
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          2         2
# 1    8960         4          4        4         1          2         2
# 2    9960         3          2        2         1          2         1
# 3    7500         4          2        2         1          2         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          2         1
# 541  2400         3          1        1         2          2         2
# 542  3620         2          1        1         1          2         2
# 543  2910         3          1        1         2          2         2
# 544  3850         3          1        2         1          2         2
#
#      hotwaterheating  airconditioning  parking  prefare  furnishingstatus  \
# ...

# %%
Y_L = W1*7420 + W2*4 + W3*2 + W4*3 + W5*1 + W6*2 + W7*2 + W8*2 + W9*1 + W10*2 + W11*1 + W12*1 + B
Y_L
# Out:
# 8201865.493539999

# %%
Predicted_price = (W1*df1.iloc[:,0] + W2*df1.iloc[:,1] + W3*df1.iloc[:,2] + W4*df1.iloc[:,3] + W5*df1.iloc[:,4] + W6*df1.iloc[:,5] + W7*df1.iloc[:,6] + W8*df1.iloc[:,7] + W9*df1.iloc[:,8] + W10*df1.iloc[:,9] + W11*df1.iloc[:,10]+ W12*df1.iloc[:,11] + B )
Predicted_price
# Out:
# 0      8.201865e+06
# 1      1.063838e+07
# 2      7.542628e+06
# 3      8.408699e+06
# 4      6.771487e+06
#            ...
# 540    3.426039e+06
# 541    2.271758e+06
# 542    2.659763e+06
# 543    2.609339e+06
# 544    3.285728e+06
# Length: 545, dtype: float64

# %%
df1.loc[:, 'predicted_price'] = Predicted_price
df1.astype(int)
# Out:
# C:\Users\Ikenna George\AppData\Local\Temp\ipykernel_22120\3781692772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[:, 'predicted_price'] = Predicted_price
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          2         2
# 1    8960         4          4        4         1          2         2
# 2    9960         3          2        2         1          2         1
# 3    7500         4          2        2         1          2         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# ...

# %%
df1 = df1.astype(int)
df1
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          2         2
# 1    8960         4          4        4         1          2         2
# 2    9960         3          2        2         1          2         1
# 3    7500         4          2        2         1          2         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          2         1
# 541  2400         3          1        1         2          2         2
# 542  3620         2          1        1         1          2         2
# 543  2910         3          1        1         2          2         2
# 544  3850         3          1        2         1          2         2
#
#      hotwaterheating  airconditioning  parking  prefare  furnishingstatus  \
# ...

# %%
Error = df1['price'] - df1['predicted_price']

# %%
rms = np.sqrt(np.mean(np.square(Error)))
print("The calculated Root Mean Square is:", rms)
# Out:
# The calculated Root Mean Square is: 1056995.0812716198

# %%
df1['predicted_price_rms'] = df1['predicted_price'] + rms
df1.astype(int)
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          2         2
# 1    8960         4          4        4         1          2         2
# 2    9960         3          2        2         1          2         1
# 3    7500         4          2        2         1          2         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          2         1
# 541  2400         3          1        1         2          2         2
# 542  3620         2          1        1         1          2         2
# 543  2910         3          1        1         2          2         2
# 544  3850         3          1        2         1          2         2
#
#      hotwaterheating  airconditioning  parking  prefare  furnishingstatus  \
# ...

# %%
df3 = df1
df3
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          2         2
# 1    8960         4          4        4         1          2         2
# 2    9960         3          2        2         1          2         1
# 3    7500         4          2        2         1          2         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          2         1
# 541  2400         3          1        1         2          2         2
# 542  3620         2          1        1         1          2         2
# 543  2910         3          1        1         2          2         2
# 544  3850         3          1        2         1          2         2
#
#      hotwaterheating  airconditioning  parking  prefare  furnishingstatus  \
# ...

# %%
df3.astype(int)
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          2         2
# 1    8960         4          4        4         1          2         2
# 2    9960         3          2        2         1          2         1
# 3    7500         4          2        2         1          2         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          2         1
# 541  2400         3          1        1         2          2         2
# 542  3620         2          1        1         1          2         2
# 543  2910         3          1        1         2          2         2
# 544  3850         3          1        2         1          2         2
#
#      hotwaterheating  airconditioning  parking  prefare  furnishingstatus  \
# ...

# %%
sns.lmplot(x = 'price',
           y = 'predicted_price_rms',
           data = df3,
           scatter_kws = {'alpha': 0.3})

# %%
df3.isnull().sum()
# Out:
# area                   0
# bedrooms               0
# bathrooms              0
# stories                0
# mainroad               0
# guestroom              0
# basement               0
# hotwaterheating        0
# airconditioning        0
# parking                0
# prefare                0
# furnishingstatus       0
# price                  0
# predicted_price        0
# predicted_price_rms    0
# dtype: int64

# %%
class MyLinearRegression:
    def __init__(self, learning_rate=0.01, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        # Initialize weights and bias
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Gradient Descent
        for _ in range(self.n_iterations):
            # Predict y_hat
            y_predicted = np.dot(X, self.weights) + self.bias

            # Calculate gradients
            dw = (1/n_samples) * np.dot(X.T, (y_predicted - y)) # Gradient of weights
            db = (1/n_samples) * np.sum(y_predicted - y)       # Gradient of bias

            # Update weights and bias
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db
        print("Training complete.")

    def predict(self, X):
        return np.dot(X, self.weights) + self.bias

# %%
X_mean = X_train.mean(axis=0)
X_std = X_train.std(axis=0)

# avoid division by zero
X_std[X_std == 0] = 1  

X_train_scaled = (X_train - X_mean) / X_std

# %%
print(X_mean.to_json())
# Out:
# {"area":5154.1444954128,"bedrooms":2.9587155963,"bathrooms":1.2660550459,"stories":1.7821100917,"mainroad":1.1422018349,"guestroom":1.8211009174,"basement":1.6422018349,"hotwaterheating":1.9495412844,"airconditioning":1.6926605505,"parking":0.6857798165,"prefare":1.7660550459,"furnishingstatus":2.0596330275}

# %%
X_std.to_json()
# Out:
# '{"area":2204.3136643403,"bedrooms":0.7478042659,"bathrooms":0.4773914143,"stories":0.8580925903,"mainroad":0.3496582444,"guestroom":0.3837080774,"basement":0.4799029745,"hotwaterheating":0.2191409994,"airconditioning":0.4619213093,"parking":0.8549407923,"prefare":0.4238239026,"furnishingstatus":0.7526956022}'

# %%
# Create a Linear Regression model
model = MyLinearRegression(learning_rate=0.01, n_iterations=1000)

# Train the model using the training data
model.fit(X_train_scaled, y_train)
# Out:
# Training complete.

# %%
X_test_scaled = (X_test - X_mean) / X_std

# %%
# Make predictions on the test data
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([5198719.71141764, 7255193.71196674, 3063680.08542042,
#        4561426.72286049, 3336833.88143045, 3564703.37181907,
#        5648642.29446227, 6415951.6650804 , 2757825.57510154,
#        2671136.90951356, 9566921.38204441, 2827989.50878344,
#        3195684.33543726, 3346776.72287221, 3709963.74305112,
#        5302079.04685874, 2987073.59676131, 4811777.50559932,
#        4378111.42752612, 3524827.88541324, 5791977.91644715,
#        5842775.23568055, 2760934.85419265, 4762200.29027464,
#        5201813.97056058, 7508416.45813863, 3254871.52038944,
#        5236651.06244378, 8171898.48832639, 3433104.03727257,
#        6441795.66389367, 3346883.12274962, 6744227.35694198,
#        4154113.64662697, 3591673.63916464, 5790001.09031531,
#        4767950.71954782, 4392607.60283766, 3220442.46236153,
#        4642303.83460178, 4523550.96700745, 3543753.99613461,
#        7236371.35278336, 4022486.87316325, 3701287.50275742,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import confusion_matrix

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'R-squared (R²): {r2:.2f}')
# Out:
# Mean Squared Error (MSE): 1771441037075.70
# R-squared (R²): 0.65

# %%
model.weights
# Out:
# array([ 518629.79428807,   60740.55440347,  523633.41796092,
#         346123.37688369, -129109.49370397,  -90763.30754756,
#        -186641.60816054, -150945.87589418, -363665.77459578,
#         193064.64791389, -266953.62817999, -158631.31377239])

# %%
model.bias
# Out:
# np.float64(4706324.198662907)

# %%
# Plot actual vs. predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs. Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2, label='Perfect prediction')
plt.title('Actual vs. Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd

# %%
### Create a Pickle file using serialization 
import pickle
pickle_out = open("Housing_price_predictor.pkl","wb")
pickle.dump(model, pickle_out)
pickle_out.close()

# %%
# Interactive prediction function
def predict_price_interactive():
    print("Enter the following details to predict house price:")
    area = float(input("Area (in sqft): "))
    bedrooms = int(input("Number of bedrooms: "))
    bathrooms = int(input("Number of bathrooms: "))
    stories = int(input("Number of stories: "))
    mainroad = int(input("Main road? (1 = yes, 2 = no): "))
    guestroom = int(input("Guest room? (1 = yes, 2 = no): "))
    basement = int(input("Basement? (1 = yes, 2 = no): "))
    hotwaterheating = int(input("Hot water heating? (1 = yes, 2 = no): "))
    airconditioning = int(input("Air conditioning? (1 = yes, 2 = no): "))
    parking = int(input("Number of parking spaces: "))
    prefare = int(input("Preferred area? (1 = yes, 2 = no): "))
    furnishingstatus = int(input("Furnishing status? (0 = unfurnished, 1 = furnished, 2 = semi-furnished): "))

    input_data = pd.DataFrame([[
        area, bedrooms, bathrooms, stories, mainroad, guestroom, basement,
        hotwaterheating, airconditioning, parking, prefare, furnishingstatus
    ]], columns= X.columns)

    predicted_price = model.predict(input_data)[0]
    print(f"\n🏠 Predicted House Price: ₹ {predicted_price:,.2f}")

# Call this to test
predict_price_interactive()
# Out:
# Enter the following details to predict house price:
